# %%
# Write a function solution(pixels) that takes an integer no of pixels as its input 
# (limit between 1 and 1000000 inclusive) and returns a list of the areas of the 
# largest squares you could color starting with the largest square first. 
# So following the example above, solution(12) would return [9, 1, 1, 1]

# Example 1
# Input: solution(15324)
# Output: 15129,169,25,1
# size = int(pixels**0.5)**2

def solution(x):
#     1 and 1000000
    if x < 1 and x > 1000000:
        return False
    res = []
    while(x>0):
        rem = math.floor(math.sqrt(x))
        r = rem**2
        res.append(r)
        x -= r
    return res
print(solution(12))

# %%
#1
import json

d = json.load(open("d.json","r"))

wrong = [k for k,v in d.items() if solution(int(k))!=v]
print(str(len(wrong))+"/"+str(len(d)))

# %%
wrong[1]

# %%
# Write a function called find(src, dest) which takes in two parameters:
# the source square, on which you start, and the destination square, which
# is where you need to land to solve the puzzle.  The function should return 
# an integer representing the smallest number of moves it will take for you to travel from 
# the source square to the destination square using a chess 
# knight's moves (that is, two squares in any direction immediately followed by one square perpendicular 
# to that direction, or vice versa, in an "L" shape).  Both the source and destination 
# squares will be an integer between 0 and 63, inclusive, and are numbered like the example chessboard below:
# Convert source and destination squares to coordinates on the board

# %%
def next_path(sx, sy, board):
    arr = [(sx, sy)]
#     print('array :',arr)
    while arr:
        x, y = arr.pop(0)
#         print('x:',x,'y:',y )
        moves = [[1,2],[-1,2],[1,-2],[-1,-2],[2,1],[-2,1],[2,-1],[-2,-1]]
        for i in moves:
          nx, ny = x + i[0], y + i[1]
#           print('nx, ny :',nx, ny)
          if 0 <= nx <= 7 and 0 <= ny <= 7:
              if board[nx][ny] is None:
                  board[nx][ny] = board[x][y] + 1
                  arr.append((nx, ny)) 

def find(src, dest):
    board = [[None for i in range(8)] for i in range(8)]
#     print(board)
#     print(board)
    sx, sy = src % 8, src // 8
    dx, dy = dest % 8, dest // 8
    board[sx][sy] = 0
    next_path(sx, sy, board)
    return board[dx][dy]


print(find(9, 30))
# Out:
# 3

# %%
pwd
# Out:
# '/home/z-4444/DS_trainning/day5'

# %%
import json


d2 = json.load(open("d2.json","r"))


wrong = [k for k,v in d2.items() if find(int(k.split(",")[0]), int(k.split(",")[1]))!=v]

print(str(len(wrong))+"/"+str(len(d2)))
# Out:
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# array : [(0, 0)]
# ...
